# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import roc_auc_score

# %%
dataset=pd.read_csv("CKD.csv")

# %%
dataset= pd.get_dummies(dataset,drop_first=True)

# %%
indep=dataset[['age', 'bp', 'al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hrmo', 'pcv',
       'wc', 'rc', 'sg_b', 'sg_c', 'sg_d', 'sg_e', 'rbc_normal', 'pc_normal',
       'pcc_present', 'ba_present', 'htn_yes', 'dm_yes', 'cad_yes',
       'appet_yes', 'pe_yes', 'ane_yes',]]
depen=dataset[['classification_yes']]

# %%
X_train,X_test,y_train,y_test=train_test_split(indep,depen,test_size=1/27,random_state=0)

# %%
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)

# %%
prea_grid= {'C':[100,20,200,3,5,500,600,900,4500], 'kernel':['linear', 'poly', 'rbf', 'sigmoid' ], 'degree':[3], 'gamma':['scale'],'shrinking':['Tre]}
grid=GridSearchCV(SVC(probability=True),prea_grid,refit=True,verbose=3,n_jobs=-1,scoring='f1_weighted')
grid.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 3
#       1 prea_grid= {'C':[100,20,200,3,5,500,600,900,4500], 'kernel':['linear', 'poly', 'rbf', 'sigmoid' ], 'degree':[3], 'gamma':['scale'],'shrinking':['True']}
#       2 grid=GridSearchCV(SVC(probability=True),prea_grid,refit=True,verbose=3,n_jobs=-1,scoring='f1_weighted')
# ----> 3 grid.fit(X_train,y_train)
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:1389, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
# -> 1389     return fit_method(estimator, *args, **kwargs)
#
# ...

# %%
y_pred=grid.predict(X_test)
cm=confusion_matrix(y_test,y_pred)
print(cm)
class_rep=classification_report(y_test,y_pred)
print(class_rep)
# Out:
# [[6 0]
#  [0 9]]
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00         6
#         True       1.00      1.00      1.00         9
#
#     accuracy                           1.00        15
#    macro avg       1.00      1.00      1.00        15
# weighted avg       1.00      1.00      1.00        15

# %%
re=grid.cv_results_
table=pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.816621      0.020543         0.058403        0.005950
# 1        0.386676      0.068949         0.042591        0.006615
# 2        0.415703      0.041188         0.050796        0.010252
# 3        5.960742      0.069386         0.289918        0.050819
# 4        2.893948      0.113131         0.164370        0.032071
# 5        2.247026      0.060896         0.146649        0.045984
# 6        0.533999      0.119224         0.042127        0.001595
# 7        0.334592      0.006042         0.039157        0.001056
# 8        0.807021      0.030321         0.059283        0.007876
# 9        0.457533      0.068145         0.046095        0.012325
# 10       0.442665      0.061298         0.040495        0.001026
# 11       5.881192      0.026240         0.272520        0.010454
# 12       2.896959      0.094102         0.177341        0.055920
# ...
